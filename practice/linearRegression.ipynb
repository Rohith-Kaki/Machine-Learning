# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('R:\Machine Learning\data\canada_per_capita_income.csv')
df.rename(columns={'year':'year','per capita income (US$)': 'pci'},inplace=True)
df.head()
# Out:
#    year          pci
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("pci")
plt.scatter(df.year,df.pci)

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.pci)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
reg.predict([[2020]])
# Out:
# C:\Users\rohit\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
import pickle

# %%
with open("Linear_model_saved",'wb') as f:
    pickle.dump(reg,f)

# %%
with open("Linear_model_saved",'rb') as f:
    house_pred = pickle.load(f)

# %%
house_pred.predict([[2020]])
# Out:
# C:\Users\rohit\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
